# %%
import math
import warnings

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
from sklearn.cross_decomposition import PLSRegression

# %matplotlib inline
sns.set_style('white')

# Suppress annoying harmless error.
warnings.filterwarnings(
    action="ignore",
    module="scipy",
    message="^internal gelsd"
)

# %%
# Number of datapoints in outcome.
n = 1000

# Number of features.
p = 10

# Create random normally distributed data for parameters.
X = np.random.normal(size=n * p).reshape((n, p))

# Create normally distributed outcome related to parameters but with noise.
y = X[:, 0] + 4 * X[:, 1] + np.random.normal(size=n * 1) + 5



# Check out correlations. First column is the outcome.
f, ax = plt.subplots(figsize=(12, 9))
corrmat = pd.DataFrame(np.insert(X, 0, y, axis=1)).corr()

# Draw the heatmap using seaborn.
sns.heatmap(corrmat, vmax=.8, square=True, cmap="RdPu")
plt.show()

# %%
# Fit a linear model with all 10 features.
regr = linear_model.LinearRegression()
regr.fit(X, y)

# Save predicted values.
Y_pred = regr.predict(X)
print('R-squared regression:', regr.score(X, y))

# Fit a linear model using Partial Least Squares Regression.
# Reduce feature space to 3 dimensions.
pls1 = PLSRegression(n_components=10)

# Reduce X to R(X) and regress on y.
pls1.fit(X, y)

# Save predicted values.
Y_PLS_pred = pls1.predict(X)
print('R-squared PLSR:', pls1.score(X, y))

# Compare the predictions of the two models
plt.scatter(Y_pred,Y_PLS_pred) 
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.9462726769335221
# R-squared PLSR: 0.9462726769335221

# %%
# Number of datapoints in outcome.
n = 1000

# Number of features.
p = 20

# Create random normally distributed data for parameters.
X1 = np.random.normal(size=n * p).reshape((n, p))

# Create normally distributed outcome related to parameters but with noise.
y1 = X1[:, 0] + 2 * X1[:, 1] + np.random.normal(size=n * 1) + 5



# Check out correlations. First column is the outcome.
f, ax = plt.subplots(figsize=(12, 9))
corrmat = pd.DataFrame(np.insert(X1, 0, y1, axis=1)).corr()

# Draw the heatmap using seaborn.
sns.heatmap(corrmat, vmax=.8, square=True, cmap="RdPu")
plt.show()

# %%
# Fit a linear model with all 10 features.
regr = linear_model.LinearRegression()
regr.fit(X1, y1)

# Save predicted values.
Y_pred1 = regr.predict(X1)
print('R-squared regression:', regr.score(X1, y1))

# Fit a linear model using Partial Least Squares Regression.
# Reduce feature space to 3 dimensions.
pls11 = PLSRegression(n_components=5)

# Reduce X to R(X) and regress on y.
pls11.fit(X1, y1)

# Save predicted values.
Y_PLS_pred1 = pls11.predict(X1)
print('R-squared PLSR:', pls11.score(X1, y1))

# Compare the predictions of the two models
plt.scatter(Y_pred1,Y_PLS_pred1) 
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.8370204475548251
# R-squared PLSR: 0.8370204473381572

# %%
# Number of datapoints in outcome.
n = 1000

# Number of features.
p = 40

# Create random normally distributed data for parameters.
X2 = np.random.normal(size=n * p).reshape((n, p))

# Create normally distributed outcome related to parameters but with noise.
y2 = X2[:, 0] + 2 * X2[:, 1] + np.random.normal(size=n * 1) + 5



# Check out correlations. First column is the outcome.
f, ax = plt.subplots(figsize=(12, 9))
corrmat = pd.DataFrame(np.insert(X2, 0, y2, axis=1)).corr()

# Draw the heatmap using seaborn.
sns.heatmap(corrmat, vmax=.8, square=True, cmap="RdPu")
plt.show()

# %%
# Fit a linear model with all 10 features.
regr = linear_model.LinearRegression()
regr.fit(X1, y1)

# Save predicted values.
Y_pred1 = regr.predict(X1)
print('R-squared regression:', regr.score(X1, y1))

# Fit a linear model using Partial Least Squares Regression.
# Reduce feature space to 3 dimensions.
pls11 = PLSRegression(n_components=5)

# Reduce X to R(X) and regress on y.
pls11.fit(X1, y1)

# Save predicted values.
Y_PLS_pred1 = pls11.predict(X1)
print('R-squared PLSR:', pls11.score(X1, y1))

# Compare the predictions of the two models
plt.scatter(Y_pred1,Y_PLS_pred1) 
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.8370204475548251
# R-squared PLSR: 0.8370204473381572

# %%
# Number of datapoints in outcome.
n = 1000

# Number of features.
p = 50

# Create random normally distributed data for parameters.
X2 = np.random.normal(size=n * p).reshape((n, p))

# Create normally distributed outcome related to parameters but with noise.
y2 = X2[:, 0] + 2 * X2[:, 1] + np.random.normal(size=n * 1) + 5



# Check out correlations. First column is the outcome.
f, ax = plt.subplots(figsize=(12, 9))
corrmat = pd.DataFrame(np.insert(X2, 0, y2, axis=1)).corr()

# Draw the heatmap using seaborn.
sns.heatmap(corrmat, vmax=.8, square=True, cmap="RdPu")
plt.show()

# %%
# Fit a linear model with all 10 features.
regr = linear_model.LinearRegression()
regr.fit(X1, y1)

# Save predicted values.
Y_pred1 = regr.predict(X1)
print('R-squared regression:', regr.score(X1, y1))

# Fit a linear model using Partial Least Squares Regression.
# Reduce feature space to 3 dimensions.
pls11 = PLSRegression(n_components=5)

# Reduce X to R(X) and regress on y.
pls11.fit(X1, y1)

# Save predicted values.
Y_PLS_pred1 = pls11.predict(X1)
print('R-squared PLSR:', pls11.score(X1, y1))

# Compare the predictions of the two models
plt.scatter(Y_pred1,Y_PLS_pred1) 
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.8370204475548251
# R-squared PLSR: 0.8370204473381572

# %%
# Number of datapoints in outcome.
n = 1000

# Number of features.
p = 60

# Create random normally distributed data for parameters.
X2 = np.random.normal(size=n * p).reshape((n, p))

# Create normally distributed outcome related to parameters but with noise.
y2 = X2[:, 0] + 2 * X2[:, 1] + np.random.normal(size=n * 1) + 5



# Check out correlations. First column is the outcome.
f, ax = plt.subplots(figsize=(12, 9))
corrmat = pd.DataFrame(np.insert(X2, 0, y2, axis=1)).corr()

# Draw the heatmap using seaborn.
sns.heatmap(corrmat, vmax=.8, square=True, cmap="RdPu")
plt.show()

# %%
# Fit a linear model with all 10 features.
regr = linear_model.LinearRegression()
regr.fit(X1, y1)

# Save predicted values.
Y_pred1 = regr.predict(X1)
print('R-squared regression:', regr.score(X1, y1))

# Fit a linear model using Partial Least Squares Regression.
# Reduce feature space to 3 dimensions.
pls11 = PLSRegression(n_components=5)

# Reduce X to R(X) and regress on y.
pls11.fit(X1, y1)

# Save predicted values.
Y_PLS_pred1 = pls11.predict(X1)
print('R-squared PLSR:', pls11.score(X1, y1))

# Compare the predictions of the two models
plt.scatter(Y_pred1,Y_PLS_pred1) 
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.8370204475548251
# R-squared PLSR: 0.8370204473381572

# %%
# Number of datapoints in outcome.
n = 1000

# Number of features.
p = 70

# Create random normally distributed data for parameters.
X2 = np.random.normal(size=n * p).reshape((n, p))

# Create normally distributed outcome related to parameters but with noise.
y2 = X2[:, 0] + 5 * X2[:, 1] + np.random.normal(size=n * 1) + 10



# Check out correlations. First column is the outcome.
f, ax = plt.subplots(figsize=(12, 9))
corrmat = pd.DataFrame(np.insert(X2, 0, y2, axis=1)).corr()

# Draw the heatmap using seaborn.
sns.heatmap(corrmat, vmax=.8, square=True, cmap="RdPu")
plt.show()

# %%
# Fit a linear model with all 10 features.
regr = linear_model.LinearRegression()
regr.fit(X1, y1)

# Save predicted values.
Y_pred1 = regr.predict(X1)
print('R-squared regression:', regr.score(X1, y1))

# Fit a linear model using Partial Least Squares Regression.
# Reduce feature space to 3 dimensions.
pls11 = PLSRegression(n_components=5)

# Reduce X to R(X) and regress on y.
pls11.fit(X1, y1)

# Save predicted values.
Y_PLS_pred1 = pls11.predict(X1)
print('R-squared PLSR:', pls11.score(X1, y1))

# Compare the predictions of the two models
plt.scatter(Y_pred1,Y_PLS_pred1) 
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.8370204475548251
# R-squared PLSR: 0.8370204473381572

# %%
# Number of datapoints in outcome.
n = 100

# Number of features.
p = 10

# Create random normally distributed data for parameters.
X = np.random.normal(size=n * p).reshape((n, p))

# Create normally distributed outcome related to parameters but with noise.
y = X[:, 0] + 2 * X[:, 1] + np.random.normal(size=n * 1) + 5



# Check out correlations. First column is the outcome.
f, ax = plt.subplots(figsize=(12, 9))
corrmat = pd.DataFrame(np.insert(X, 0, y, axis=1)).corr()

# Draw the heatmap using seaborn.
sns.heatmap(corrmat, vmax=.8, square=True, cmap="RdPu")
plt.show()

# %%
# Fit a linear model with all 10 features.
regr = linear_model.LinearRegression()
regr.fit(X1, y1)

# Save predicted values.
Y_pred1 = regr.predict(X1)
print('R-squared regression:', regr.score(X1, y1))

# Fit a linear model using Partial Least Squares Regression.
# Reduce feature space to 3 dimensions.
pls11 = PLSRegression(n_components=5)

# Reduce X to R(X) and regress on y.
pls11.fit(X1, y1)

# Save predicted values.
Y_PLS_pred1 = pls11.predict(X1)
print('R-squared PLSR:', pls11.score(X1, y1))

# Compare the predictions of the two models
plt.scatter(Y_pred1,Y_PLS_pred1) 
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.8370204475548251
# R-squared PLSR: 0.8370204473381572

# %% [markdown]
# ## When we change the n and keep the p the same, it went up to 83% for both R-Squared regression and R-Squared PLSR.
# ## When we change the p and keep the n the same, it also went up to 83% for both R-Squared as well.
# ## We can get stronger R-Squared, the more we lower the number of datapoints. If you lower to 10, you get 100%.
# ## Tried to change the feature space around, but it does not do anything.
#
# ## If we change the y value from 2, to let say, 4, our R-Square will increase from 83% to 94%, and if we change to 6,
# ## it will then increase to 97%. Thus, having a lot of noise will increase your R-Square rate, but it does not mean that
# ## a good thing.
