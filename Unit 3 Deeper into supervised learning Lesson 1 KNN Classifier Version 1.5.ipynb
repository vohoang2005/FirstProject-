# %%
# %matplotlib inline
from sklearn import linear_model
import statsmodels.formula.api as smf
from IPython.display import display
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import math
import warnings

# %%
NY_Crime = pd.read_csv('NYM.csv')
NY_Crime.head()
# Out:
#                              Table 8  Unnamed: 1      Unnamed: 2  \
# 0                           NEW YORK         NaN             NaN
# 1  Offenses Known to Law Enforcement         NaN             NaN
# 2                      by City, 2013         NaN             NaN
# 3                               City  Population  Violent\ncrime
# 4                      Adams Village       1,861               0
#
#                                Unnamed: 3                    Unnamed: 4  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3  Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1
# 4                                       0                           NaN
#
#                     Unnamed: 5 Unnamed: 6           Unnamed: 7  \
# 0                          NaN        NaN                  NaN
# 1                                     NaN                  NaN
# 2                          NaN        NaN                  NaN
# 3  Rape\n(legacy\ndefinition)2    Robbery  Aggravated\nassault
# 4                            0          0                    0
#
#         Unnamed: 8 Unnamed: 9      Unnamed: 10            Unnamed: 11  \
# 0              NaN        NaN              NaN                    NaN
# 1              NaN        NaN              NaN                    NaN
# 2              NaN        NaN              NaN                    NaN
# 3  Property\ncrime   Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft
# 4               12          2               10                      0
#
#   Unnamed: 12  Unnamed: 13
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3      Arson3          NaN
# 4           0          NaN

# %%
NY_Crime.columns = NY_Crime.iloc[3]
NY_Crime.head()
# Out:
# 3                               City  Population  Violent\ncrime  \
# 0                           NEW YORK         NaN             NaN
# 1  Offenses Known to Law Enforcement         NaN             NaN
# 2                      by City, 2013         NaN             NaN
# 3                               City  Population  Violent\ncrime
# 4                      Adams Village       1,861               0
#
# 3  Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3  Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1
# 4                                       0                           NaN
#
# 3  Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault  Property\ncrime  \
# 0                          NaN      NaN                  NaN              NaN
# 1                                   NaN                  NaN              NaN
# 2                          NaN      NaN                  NaN              NaN
# 3  Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault  Property\ncrime
# 4                            0        0                    0               12
#
# 3  Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft  Arson3  NaN
# 0       NaN              NaN                    NaN     NaN  NaN
# 1       NaN              NaN                    NaN     NaN  NaN
# 2       NaN              NaN                    NaN     NaN  NaN
# 3  Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft  Arson3  NaN
# 4         2               10                      0       0  NaN

# %%
NY_Crime = NY_Crime.drop(NY_Crime.index[:4])
NY_Crime.head()
# Out:
# 3                      City Population Violent\ncrime  \
# 4             Adams Village      1,861              0
# 5  Addison Town and Village      2,577              3
# 6             Akron Village      2,846              3
# 7                    Albany     97,956            791
# 8            Albion Village      6,388             23
#
# 3 Murder and\nnonnegligent\nmanslaughter Rape\n(revised\ndefinition)1  \
# 4                                      0                          NaN
# 5                                      0                          NaN
# 6                                      0                          NaN
# 7                                      8                          NaN
# 8                                      0                          NaN
#
# 3 Rape\n(legacy\ndefinition)2 Robbery Aggravated\nassault Property\ncrime  \
# 4                           0       0                   0              12
# 5                           0       0                   3              24
# 6                           0       0                   3              16
# 7                          30     227                 526           4,090
# 8                           3       4                  16             223
#
# 3 Burglary Larceny-\ntheft Motor\nvehicle\ntheft Arson3  NaN
# 4        2              10                     0      0  NaN
# 5        3              20                     1      0  NaN
# 6        1              15                     0      0  NaN
# 7      705           3,243                   142    NaN  NaN
# 8       53             165                     5    NaN  NaN

# %%
NY_Crime = NY_Crime.reset_index(drop=True)

# %%
NY_Crime.drop(labels=[348, 349, 350], axis=0, inplace=True)

# %%
NY_Crime.head()
# Out:
# 3                      City Population Violent\ncrime  \
# 0             Adams Village      1,861              0
# 1  Addison Town and Village      2,577              3
# 2             Akron Village      2,846              3
# 3                    Albany     97,956            791
# 4            Albion Village      6,388             23
#
# 3 Murder and\nnonnegligent\nmanslaughter Rape\n(revised\ndefinition)1  \
# 0                                      0                          NaN
# 1                                      0                          NaN
# 2                                      0                          NaN
# 3                                      8                          NaN
# 4                                      0                          NaN
#
# 3 Rape\n(legacy\ndefinition)2 Robbery Aggravated\nassault Property\ncrime  \
# 0                           0       0                   0              12
# 1                           0       0                   3              24
# 2                           0       0                   3              16
# 3                          30     227                 526           4,090
# 4                           3       4                  16             223
#
# 3 Burglary Larceny-\ntheft Motor\nvehicle\ntheft Arson3  NaN
# 0        2              10                     0      0  NaN
# 1        3              20                     1      0  NaN
# 2        1              15                     0      0  NaN
# 3      705           3,243                   142    NaN  NaN
# 4       53             165                     5    NaN  NaN

# %%
NY_Crime.rename(columns = {"Murder and\nnonnegligent\nmanslaughter" : 'Murder'}, inplace=True)
NY_Crime.rename(columns = {"Property\ncrime" : 'Property_Crime'}, inplace=True)
NY_Crime.head()
# Out:
# 3                      City Population Violent\ncrime Murder  \
# 0             Adams Village      1,861              0      0
# 1  Addison Town and Village      2,577              3      0
# 2             Akron Village      2,846              3      0
# 3                    Albany     97,956            791      8
# 4            Albion Village      6,388             23      0
#
# 3 Rape\n(revised\ndefinition)1 Rape\n(legacy\ndefinition)2 Robbery  \
# 0                          NaN                           0       0
# 1                          NaN                           0       0
# 2                          NaN                           0       0
# 3                          NaN                          30     227
# 4                          NaN                           3       4
#
# 3 Aggravated\nassault Property_Crime Burglary Larceny-\ntheft  \
# 0                   0             12        2              10
# 1                   3             24        3              20
# 2                   3             16        1              15
# 3                 526          4,090      705           3,243
# 4                  16            223       53             165
#
# 3 Motor\nvehicle\ntheft Arson3  NaN
# 0                     0      0  NaN
# 1                     1      0  NaN
# 2                     0      0  NaN
# 3                   142    NaN  NaN
# 4                     5    NaN  NaN

# %%
NY_Crime['Murder'] = NY_Crime['Murder'].str.replace(",", "")
NY_Crime['Robbery'] = NY_Crime['Robbery'].str.replace(",", "")
NY_Crime['Property_Crime'] = NY_Crime['Property_Crime'].str.replace(",", "")
NY_Crime['Property_Crime'] = NY_Crime['Property_Crime'].astype(int)
NY_Crime['Murder'] = NY_Crime['Murder'].astype(int)
NY_Crime['Robbery'] = NY_Crime['Robbery'].astype(int)
NY_Crime['Population'] = NY_Crime['Population'].str.replace(",", "")
NY_Crime['Population'] = NY_Crime.Population.astype(int)

# %%
NY_Crime['Murder2'] = NY_Crime['Murder'].apply(lambda x: '1' if x > 0 else '0')
NY_Crime['Robbery2'] = NY_Crime['Robbery'].apply(lambda x: '1' if x > 0 else '0')
NY_Crime.head()
# Out:
# 3                      City  Population Violent\ncrime  Murder  \
# 0             Adams Village        1861              0       0
# 1  Addison Town and Village        2577              3       0
# 2             Akron Village        2846              3       0
# 3                    Albany       97956            791       8
# 4            Albion Village        6388             23       0
#
# 3 Rape\n(revised\ndefinition)1 Rape\n(legacy\ndefinition)2  Robbery  \
# 0                          NaN                           0        0
# 1                          NaN                           0        0
# 2                          NaN                           0        0
# 3                          NaN                          30      227
# 4                          NaN                           3        4
#
# 3 Aggravated\nassault  Property_Crime Burglary Larceny-\ntheft  \
# 0                   0              12        2              10
# 1                   3              24        3              20
# 2                   3              16        1              15
# 3                 526            4090      705           3,243
# 4                  16             223       53             165
#
# 3 Motor\nvehicle\ntheft Arson3  NaN Murder2 Robbery2
# 0                     0      0  NaN       0        0
# 1                     1      0  NaN       0        0
# 2                     0      0  NaN       0        0
# 3                   142    NaN  NaN       1        1
# 4                     5    NaN  NaN       0        1

# %%
NY_Crime = NY_Crime[['Property_Crime', 'Population', 'Robbery2']]
NY_Crime.drop(labels=[0], axis=0, inplace=True)
NY_Crime.head()
# Out:
# 3  Property_Crime  Population Robbery2
# 1              24        2577        0
# 2              16        2846        0
# 3            4090       97956        1
# 4             223        6388        1
# 5              46        4089        1

# %%
NY_Crimes = NY_Crime

# %%
# Look at our data.
NY_Crimes['Population'] = NY_Crime['Population']
NY_Crimes['Property_Crime'] = NY_Crime['Property_Crime']
NY_Crimes['Robbery2'] = NY_Crime['Robbery2']

# %%
NY_Crimes.head()
# Out:
# 3  Property_Crime  Population Robbery2
# 1              24        2577        0
# 2              16        2846        0
# 3            4090       97956        1
# 4             223        6388        1
# 5              46        4089        1

# %%
NY_Crimes = pd.DataFrame()

NY_Crimes['Population'] = NY_Crime['Population']
NY_Crimes['Robbery2'] = NY_Crime['Robbery2']
NY_Crimes['Property_Crime'] = NY_Crime['Property_Crime']

# %%
plt.scatter(
    NY_Crimes[NY_Crimes['Robbery2'] == 1].Population,
    NY_Crimes[NY_Crimes['Robbery2'] == 1].Property_Crime,
    color='red'
)
plt.scatter(
    NY_Crimes[NY_Crimes['Robbery2'] == 0].Population,
    NY_Crimes[NY_Crimes['Robbery2'] == 0].Property_Crime,
    color='blue'
)

plt.legend(['Crime Committed', 'None Committed'])
plt.title('Population and Property Crime')
plt.xlabel('Population')
plt.ylabel('Property_Crime')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
neighbors = KNeighborsClassifier(n_neighbors=1)
X = NY_Crime[['Population', 'Property_Crime']]
Y = NY_Crime.Robbery2
neighbors.fit(X,Y)

## Predict for a song with 24 loudness that's 190 seconds long.
neighbors.predict([[250, 19]])
# Out:
# array(['0'], dtype=object)

# %%
neighbors1 = KNeighborsClassifier(n_neighbors=10)
X = NY_Crime[['Population', 'Property_Crime']]
Y = NY_Crime.Robbery2
neighbors.fit(X,Y)

## Predict for a song with 24 loudness that's 190 seconds long.
print(neighbors.predict([[25, 19]]))
print(neighbors.predict_proba([[25, 19]]))
# Out:
# ['0']
# [[1. 0.]]

# %%
# Our data. Converting from data frames to arrays for the mesh.
X = np.array(X)
Y = np.array(Y)

# Mesh size.
h = 4.0

# Plot the decision boundary. We assign a color to each point in the mesh.
x_min = X[:, 0].min() - .5
x_max = X[:, 0].max() + .5
y_min = X[:, 1].min() - .5
y_max = X[:, 1].max() + .5
xx, yy = np.meshgrid(
    np.arange(x_min, x_max, h),
    np.arange(y_min, y_max, h)
)
Z = neighbors.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot.
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(6, 4))
plt.set_cmap(plt.cm.Paired)
plt.pcolormesh(xx, yy, Z)

# Add the training points to the plot.
plt.scatter(X[:, 0], X[:, 1], c=Y)
plt.xlabel('Loudness')
plt.ylabel('Duration')
plt.title('Mesh visualization')

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-170-f0e3f55eda6a> in <module>()
#      13 xx, yy = np.meshgrid(
#      14     np.arange(x_min, x_max, h),
# ---> 15     np.arange(y_min, y_max, h)
#      16 )
#      17 Z = neighbors.predict(np.c_[xx.ravel(), yy.ravel()])
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in meshgrid(*xi, **kwargs)
#    4696
#    4697     if copy_:
# -> 4698         output = [x.copy() for x in output]
#    4699
#    4700     return output
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in <listcomp>(.0)
#    4696
#    4697     if copy_:
# -> 4698         output = [x.copy() for x in output]
#    4699
#    4700     return output
#
# MemoryError:

# %%
## The Mesh look vertical because of the Population is very big I believe..
## If we use another datapoint instead of Population, it would look better.
